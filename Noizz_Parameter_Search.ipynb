# %%
import subprocess
import optuna
import random
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from tqdm import tqdm
from typing import Tuple, List
from scipy.signal import resample
import os
import glob
from pathlib import Path
import yaml
from sklearn.metrics import mean_absolute_error as MAE
import json

# %%
SEED = 0xDEAD
np.random.seed(SEED)
random.seed(SEED)

# %%
def delete_simulated_files():
    simulated_files = list(map(str, Path('.\\').glob(f'Noizz*.csv')))
    for sim_file in simulated_files:
        os.remove(sim_file)

delete_simulated_files()

# %%
def segment_signal(signal, segment_length, step=None, overlap=None, apply_window=True):
    if step is not None:
        segments = [
            signal[i : i + segment_length]
            for i in range(0, len(signal) - segment_length + 1, step)
        ]
    elif overlap is not None:
        step = int(segment_length * (1 - overlap))
        segments = [
            signal[i : i + segment_length]
            for i in range(0, len(signal) - segment_length + 1, step)
        ]
    else:
        raise ValueError("Either 'step' or 'overlap' must be specified.")
    return np.array(segments)


def time_to_freq_transform(data, f_sampling, db=True, cutoff_freq=None):
    if data.ndim != 1:
        raise ValueError(
            f"Input data must be a 1D NumPy array. Got shape {data.shape}."
        )
    n = data.shape[0] 
    yf = np.fft.rfft(data) 
    freqs = np.fft.rfftfreq(n, d=1 / f_sampling) 
    if cutoff_freq is not None:
        mask = freqs < cutoff_freq 
        yf = yf[mask]
        freqs = freqs[mask]
    yf = np.abs(yf)  
    if db:
        eps = np.finfo(float).eps  
        yf = 20 * np.log10(yf + eps)  
    return yf, freqs


def perform_fft_on_segments(
    segments, f_sampling, db=True, cutoff_freq=250, remove_dc=False
):
    segs = segments.copy()
    if remove_dc:
        segs -= segs.mean(axis=1, keepdims=True)
    num_segments, segment_length = segs.shape
    full_freqs = np.fft.rfftfreq(segment_length, d=1 / f_sampling)
    cutoff_mask = full_freqs < cutoff_freq
    fft_output_length = np.sum(cutoff_mask)

    fft_segments = np.zeros((num_segments, fft_output_length))
    for i in range(num_segments):
        fft_segments[i], freqs = time_to_freq_transform(
            segments[i], f_sampling, db=db, cutoff_freq=cutoff_freq
        )
    return fft_segments, freqs

# %%
def get_mean_and_std(fft_segments):
    spectrum_mean = np.mean(fft_segments, axis=0)
    spectrum_std = np.std(fft_segments, axis=0)
    return spectrum_mean, spectrum_std


def tight_plots(ax):
    ax.legend(fontsize=9)
    plt.tight_layout()
    plt.show()


def plot_single_segment_with_uncertainty(fft_segments, 
                                         x_values=None, 
                                         max_points=1000, 
                                         n_std=2, 
                                         title="Spectrum with Uncertainty",
                                         axis_labels=None, 
                                         highlight_freqs=None, 
                                         method='closest',
                                         inplace=True):
    spectrum_mean = np.mean(fft_segments, axis=0)
    spectrum_std = np.std(fft_segments, axis=0) * n_std 
    if max_points is not None and len(spectrum_mean) > max_points:
        spectrum_mean = resample(spectrum_mean, max_points)
        spectrum_std = resample(spectrum_std, max_points)
        if x_values is not None:
            if len(x_values.shape) == 1:
                x_values = resample(x_values, max_points)
            else:
                x_values = resample(x_values, max_points)
        else:
            x_values = np.linspace(0, len(spectrum_mean), len(spectrum_mean))
    else:
        if x_values is None:
            x_values = np.linspace(0, len(spectrum_mean), len(spectrum_mean))

    x_label, y_label = axis_labels if axis_labels else ('Frequency, Hz', 'Power, dB')
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(x_values, spectrum_mean, linewidth=2.0, color='blue', label='Mean Spectrum')
    ax.fill_between(
        x_values,
        spectrum_mean - spectrum_std,
        spectrum_mean + spectrum_std,
        color='blue',
        alpha=0.2,
        label=f'Uncertainty (±{n_std} SD)'
    )
    ax.plot(x_values, spectrum_mean - spectrum_std, linewidth=1.0, color='darkblue', linestyle='--')
    ax.plot(x_values, spectrum_mean + spectrum_std, linewidth=1.0, color='darkblue', linestyle='--')
    if highlight_freqs is not None and len(highlight_freqs) > 0:
        for freq in highlight_freqs:
            if method == 'closest':
                closest_idx = np.abs(x_values - freq).argmin()
                ax.scatter(x_values[closest_idx], spectrum_mean[closest_idx], color='red', s=50)
    ax.set_title(title, fontsize=10, fontweight='bold')
    ax.set_xlabel(x_label, fontsize=9)
    ax.set_ylabel(y_label, fontsize=9)
    ax.grid(True, linestyle='--', linewidth=0.5)
    if inplace:
        tight_plots(ax)
    return fig, ax

# %%
def create_metadata_df(base_dir: str, state2name: dict | None = None) -> pd.DataFrame:
    csv_pattern = os.path.join(base_dir, "experiment_*", "current", "*", "*", "*.csv")
    csv_files = glob.glob(csv_pattern)
    metadata_list = []
    for file_path in csv_files:
        parts = file_path.split(os.sep)
        try:
            experiment = parts[-5]  
            load_folder = parts[-3] 
            phase = parts[-2] 
            base_id = os.path.splitext(os.path.basename(file_path))[0]
            measurement_id = base_id + f"_{phase}"
        except IndexError as e:
            print(f"File path {file_path} does not match expected structure: {e}")
            continue
        try:
            load_parts = load_folder.split("_")
            if len(load_parts) >= 3:
                state = load_parts[0][0] 
                load_condition = load_parts[-1] 
            else:
                state = None
                load_condition = load_folder
        except Exception as e:
            print(f"Error parsing load folder {load_folder} in file {file_path}: {e}")
            state, load_condition = None, None
        try:
            df = pd.read_csv(file_path, header=0, index_col=0)
        except Exception as e:
            print(f"Error reading file {file_path}: {e}")
            continue
        df = df.dropna(axis=1, how="all")
        num_observations = df.shape[0]
        if state2name is not None:
            try:
                state = state2name[int(state)]
            except KeyError:
                print(f"Fault type {state} not found in mapping.")
                state = None
        meta_entry = {
            "measurement_id": measurement_id,
            "base_id": base_id,
            "experiment": experiment,
            "state": state,
            "load_condition": load_condition,
            "phase": phase,
            "num_observations": num_observations,
            "file_path": file_path,
            "engine_cfg_path": f"dataset/engine_2/engine.yml",
        }
        metadata_list.append(meta_entry)
    if metadata_list:
        metadata_df = pd.DataFrame(metadata_list)
        metadata_df.set_index("measurement_id", inplace=True)
    else:
        metadata_df = pd.DataFrame(
            columns=[
                "experiment",
                "state",
                "load_condition",
                "phase",
                "num_observations",
                "file_path",
                "engine_cfg_path",
            ]
        )
    return metadata_df


def load_measurement(measurement_id: str, metadata_df: pd.DataFrame) -> pd.DataFrame:
    if measurement_id not in metadata_df.index:
        raise KeyError(f"Measurement {measurement_id} not found in metadata.")
    file_path = metadata_df.loc[measurement_id, "file_path"]
    try:
        df = pd.read_csv(file_path, header=0, index_col=0)
    except Exception as e:
        raise Exception(f"Error reading file {file_path}: {e}")
    df = df.dropna(axis=1, how="all")
    df.columns = ["Time", "Current"]
    df.set_index("Time", inplace=True)
    df.sort_index(inplace=True)
    return df


def preprocessing(
    metadata_df: pd.DataFrame,
    out_dir: str,
    segment_length: int,
    step: int,
    f_sampling: int,
    cutoff_freq: int,
    apply_window: bool = False,
    db: bool = True,
) -> Tuple[np.ndarray, pd.DataFrame, np.ndarray]:
    seg_meta_rows: List[dict] = []
    seg_arrays: List[np.ndarray] = []
    for m_id, meta in tqdm(metadata_df.iterrows(),
                           total=len(metadata_df),
                           desc="pre-processing"):
        df = load_measurement(m_id, metadata_df)
        current = df["Current"].dropna().values
        windows = segment_signal(
            current,
            segment_length=segment_length,
            step=step,
            apply_window=apply_window,
        )
        fft_windows, freqs = perform_fft_on_segments(
            windows,
            f_sampling=f_sampling,
            cutoff_freq=cutoff_freq,
            db=db,
        )
        n_segments = fft_windows.shape[0]
        for s_idx in range(n_segments):
            start_t = df.index[s_idx * step]
            end_t   = df.index[s_idx * step + segment_length - 1]
            seg_meta_rows.append({
                "measurement_id": m_id,
                "segment_idx":    s_idx,
                "start_time":     float(start_t),
                "end_time":       float(end_t),
                "state":          meta["state"],
                "binary_label":   0 if meta["state"] == "normal" else 1,
                "multiclass_label": meta["state"],
                "phase":          int(meta["phase"]),
                "load_condition": meta["load_condition"],
                "experiment":     meta["experiment"],
            })
        seg_arrays.append(fft_windows.astype(np.float32))
    segments = np.vstack(seg_arrays) 
    seg_meta_df = (
        pd.DataFrame(seg_meta_rows)
          .set_index(["measurement_id", "segment_idx"])
    )
    os.makedirs(out_dir, exist_ok=True)
    np.save(os.path.join(out_dir, "segments.npy"), segments)
    np.save(os.path.join(out_dir, "freqs.npy"), freqs)
    seg_meta_df.to_csv(os.path.join(out_dir, "segments_metadata.csv"))
    return segments, seg_meta_df, freqs

# %%
with open("training_configs/train_engine-2.yml", "r") as f:
    train_params = yaml.safe_load(f)

f_sampling = train_params["processing_parameters"]["f_sampling"]
shift = train_params["processing_parameters"]["shift"]
segment_length = train_params["processing_parameters"]["segment_length"]
cutoff_freq = train_params["processing_parameters"]["cutoff_freq"]
peak_type = train_params["processing_parameters"]["peak_type"]
peak_segment = train_params["processing_parameters"]["peak_segment"]
amplitude_range = tuple(train_params["processing_parameters"]["amplitude_range"])
sigma_range = tuple(train_params["processing_parameters"]["sigma_range"])
noise_factor = train_params["processing_parameters"]["noise_factor"]
num_epochs_binary = train_params["training_parameters"]["num_epochs_binary"]
num_epochs_multi = train_params["training_parameters"]["num_epochs_multi"]
batch_size = train_params["data_parameters"]["batch_size"]
normalization_method = train_params["dataset_parameters"]["normalization_method"]

train_params
# Out:
# {'engineLabel': 'engine_2',
#  'task': 'binary',
#  'model': 'ResNet',
#  'test_run': False,
#  'comet_online': False,
#  'seed': 42,
#  'processing_parameters': {'f_sampling': 4098,
#   'shift': 20,
#   'segment_length': 10000,
#   'cutoff_freq': 250,
#   'db': True,
#   'peak_type': 'gaussian',
#   'peak_segment': 4,
#   'amplitude_range': [0.5, 20.0],
#   'sigma_range': [0.5, 1.5],
#   'noise_factor': 0.0,
#   'include_negative_peaks': True,
#   'random_peak_position': True,
#   'fault_types_to_use': ['inter-turn short circuits', 'rotor bar defect'],
#   'loads_to_use': [0, 20, 40, 60, 80, 100],
#   'phases_to_use': [1, 2, 3]},
#  'model_parameters': {'attention_module': False, 'dropout': 0.2},
#  'training_parameters': {'num_epochs_binary': 30,
#   'num_epochs_multi': 30,
#   'initial_lr': 0.001,
#   'patience': 10},
#  'data_parameters': {'batch_size': 4096},
#  'dataset_parameters': {'batch_size': 4096,
#   'normalization_method': 'min-max',
#   'normalization_mode': 'global',
#   'real_fault_train': 0,
#   'test_size': 0.3,
#   'val_size': 0.2,
#   'train_dataset_cls': 'HybridAugFaultDataset',
#   'train_dataset_kwargs': {'K': 2, 'R': 1, 'cache': True, 'keep_orig': True}}}

# %%
state2name = {
    1: "rotor bar defect",
    2: "normal",
    3: "bearing defect",
    4: "inter-turn short circuits"
}
base_dir = "dataset/engine_2"
path2metadata = os.path.join(base_dir, 'metadata.csv')
if os.path.isfile(path2metadata):
    metadata_df = pd.read_csv(os.path.join(path2metadata))
    metadata_df.set_index('measurement_id', inplace=True)
else:
    metadata_df = create_metadata_df(base_dir, state2name)
    metadata_df.to_csv(path2metadata)
real_df = metadata_df[(metadata_df.state == 'normal') & (metadata_df.load_condition == 100)]
real_df.head()
# Out:
#                    base_id    experiment   state  load_condition  phase  \
# measurement_id
# 1727791012_1    1727791012  experiment_1  normal             100      1
# 1727791211_1    1727791211  experiment_1  normal             100      1
# 1727790910_1    1727790910  experiment_1  normal             100      1
# 1727790870_1    1727790870  experiment_1  normal             100      1
# 1727791170_1    1727791170  experiment_1  normal             100      1
#
#                 num_observations  \
# measurement_id
# 1727791012_1               16384
# 1727791211_1               16384
# 1727790910_1               16384
# 1727790870_1               16384
# 1727791170_1               16384
#
#                                                         file_path  \
# measurement_id
# 1727791012_1    ./dataset/engine_2/experiment_1/current/2nd_lo...
# 1727791211_1    ./dataset/engine_2/experiment_1/current/2nd_lo...
# 1727790910_1    ./dataset/engine_2/experiment_1/current/2nd_lo...
# 1727790870_1    ./dataset/engine_2/experiment_1/current/2nd_lo...
# 1727791170_1    ./dataset/engine_2/experiment_1/current/2nd_lo...
#
#                               engine_cfg_path
# measurement_id
# 1727791012_1    ./dataset/engine_2/engine.yml
# 1727791211_1    ./dataset/engine_2/engine.yml
# 1727790910_1    ./dataset/engine_2/engine.yml
# 1727790870_1    ./dataset/engine_2/engine.yml
# 1727791170_1    ./dataset/engine_2/engine.yml

# %%
real_seg = {}
real_freqs = {}

real_seg[1], _, real_freqs[1] = preprocessing(real_df[real_df.phase == 1],
                                              'real_data_1',
                                              segment_length=segment_length,
                                              step=shift,
                                              f_sampling=f_sampling,
                                              cutoff_freq=cutoff_freq
                                              )

real_seg[2], _, real_freqs[2] = preprocessing(real_df[real_df.phase == 2],
                                              'real_data_2',
                                              segment_length=segment_length,
                                              step=shift,
                                              f_sampling=f_sampling,
                                              cutoff_freq=cutoff_freq
                                              )

real_seg[3], _, real_freqs[3] = preprocessing(real_df[real_df.phase == 3],
                                              'real_data_3',
                                              segment_length=segment_length,
                                              step=shift,
                                              f_sampling=f_sampling,
                                              cutoff_freq=cutoff_freq
                                              )
# Out:
# pre-processing: 100%|██████████| 21/21 [00:02<00:00, 10.16it/s]
# pre-processing: 100%|██████████| 21/21 [00:01<00:00, 11.37it/s]
# pre-processing: 100%|██████████| 21/21 [00:01<00:00, 11.32it/s]

# %%
real_means = {}
real_std = {}

for phase in range(1, 4):
    real_means[phase], real_std[phase] = get_mean_and_std(real_seg[phase])
    fig, ax = plot_single_segment_with_uncertainty(real_seg[phase], 
                                                   x_values=real_freqs[phase], 
                                                   n_std=3, 
                                                   title=f'Average Spectrum (real, all csv, phase {phase})',
                                                   inplace=True)

# %%
test_value = 0.004
subprocess.run(f'matlab -batch "Noizz = {test_value}; Find_Best_Noizz"')
# Out:
# CompletedProcess(args='matlab -batch "Noizz = 0.004; Find_Best_Noizz"', returncode=0)

# %%
def get_phase(x):
    phase = x.split('\\')[-1].split('_')[-1].split('.')[0]
    return 1 if phase == 'phaseA' else 2 if phase == 'phaseB' else 3

def get_num_observations(x):
    return pd.read_csv(x).shape[0]

def get_measurement_id(x):
    return f'{x.state}_{x.phase}'

# %%
simulated_files = list(map(str, Path('.\\').glob(f'Noizz{test_value}*.csv')))
simulated_df = pd.DataFrame({'file_path': simulated_files})
simulated_df['state'] = 'normal'
simulated_df['load_condition'] = 100
simulated_df['experiment'] = 'experiment_2'
simulated_df['phase'] = simulated_df.file_path.apply(get_phase)
simulated_df['num_observations'] = simulated_df.file_path.apply(get_num_observations)
simulated_df['measurement_id'] = simulated_df.apply(get_measurement_id, axis=1)
simulated_df = simulated_df.reset_index(drop=True).set_index('measurement_id')
simulated_df.head()
# Out:
#                                     file_path   state  load_condition  \
# measurement_id
# normal_1        Noizz0.004_load100_phaseA.csv  normal             100
# normal_2        Noizz0.004_load100_phaseB.csv  normal             100
# normal_3        Noizz0.004_load100_phaseC.csv  normal             100
#
#                   experiment  phase  num_observations
# measurement_id
# normal_1        experiment_2      1            450000
# normal_2        experiment_2      2            450000
# normal_3        experiment_2      3            450000

# %%
sim_seg = {}
sim_freqs = {}

sim_seg[1], _, sim_freqs[1] = preprocessing(simulated_df[simulated_df.phase == 1],
                                            'sim_data_1',
                                            segment_length=segment_length,
                                            step=shift,
                                            f_sampling=f_sampling,
                                            cutoff_freq=cutoff_freq
                                            )

sim_seg[2], _, sim_freqs[2] = preprocessing(simulated_df[simulated_df.phase == 2],
                                            'sim_data_2',
                                            segment_length=segment_length,
                                            step=shift,
                                            f_sampling=f_sampling,
                                            cutoff_freq=cutoff_freq
                                            )

sim_seg[3], _, sim_freqs[3] = preprocessing(simulated_df[simulated_df.phase == 3],
                                            'sim_data_3',
                                            segment_length=segment_length,
                                            step=shift,
                                            f_sampling=f_sampling,
                                            cutoff_freq=cutoff_freq
                                            )
# Out:
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.21s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.51s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.10s/it]

# %%
sim_means = {}
sim_std = {}

for phase in range(1, 4):
    sim_means[phase], sim_std[phase] = get_mean_and_std(sim_seg[phase])
    fig, ax = plot_single_segment_with_uncertainty(sim_seg[phase], 
                                                   x_values=sim_freqs[phase], 
                                                   n_std=3, 
                                                   title=f'Average Spectrum (simulated, all csv, phase {phase}, Noizz = {test_value})',
                                                   inplace=True)

# %%
opt_mean_Noizz = opt_std_Noizz = -1
opt_mean_mae = opt_std_mae = float('inf')
for Noizz in np.logspace(-4, 1, num=100):
    delete_simulated_files()
    subprocess.run(f'matlab -batch "Noizz = {Noizz}; Find_Best_Noizz"')
    simulated_files = list(map(str, Path('.\\').glob(f'Noizz*.csv')))
    simulated_df = pd.DataFrame({'file_path': simulated_files})
    simulated_df['state'] = 'normal'
    simulated_df['load_condition'] = 100
    simulated_df['experiment'] = 'experiment_2'
    simulated_df['phase'] = simulated_df.file_path.apply(get_phase)
    simulated_df['num_observations'] = simulated_df.file_path.apply(get_num_observations)
    simulated_df['measurement_id'] = simulated_df.apply(get_measurement_id, axis=1)
    simulated_df = simulated_df.reset_index(drop=True).set_index('measurement_id')
    sim_seg[1], _, sim_freqs[1] = preprocessing(simulated_df[simulated_df.phase == 1],
                                                'sim_data_1',
                                                segment_length=segment_length,
                                                step=shift,
                                                f_sampling=f_sampling,
                                                cutoff_freq=cutoff_freq
                                                )
    sim_seg[2], _, sim_freqs[2] = preprocessing(simulated_df[simulated_df.phase == 2],
                                                'sim_data_2',
                                                segment_length=segment_length,
                                                step=shift,
                                                f_sampling=f_sampling,
                                                cutoff_freq=cutoff_freq
                                                )
    sim_seg[3], _, sim_freqs[3] = preprocessing(simulated_df[simulated_df.phase == 3],
                                                'sim_data_3',
                                                segment_length=segment_length,
                                                step=shift,
                                                f_sampling=f_sampling,
                                                cutoff_freq=cutoff_freq
                                                )
    all_mean_mae = 0
    all_std_mae = 0
    for phase in range(1, 4):
        sim_means[phase], sim_std[phase] = get_mean_and_std(sim_seg[phase])
        all_std_mae += MAE(real_std[phase], sim_std[phase]) 
        all_mean_mae = MAE(real_means[phase], sim_means[phase])
    if all_mean_mae < opt_mean_mae:
        opt_mean_Noizz = Noizz
        opt_mean_mae = all_mean_mae
    if all_std_mae < opt_std_mae:
        opt_std_Noizz = Noizz
        opt_std_mae = all_std_mae
# Out:
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.68s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.12s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.55s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.36s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.68s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.71s/it]
# pre-processing: 100%|██████████| 1/1 [00:06<00:00,  6.58s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.61s/it]
# pre-processing: 100%|██████████| 1/1 [00:06<00:00,  6.24s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.73s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.39s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.87s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.35s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.07s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.24s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.16s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.23s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.07s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.63s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.85s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.55s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.95s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.78s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.00s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.16s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.18s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.92s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.70s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.68s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.42s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.18s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.10s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.82s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.68s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.50s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.35s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.59s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.53s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.31s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.97s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.72s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.29s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.50s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.49s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.47s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.91s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.66s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.24s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.28s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.49s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.28s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.22s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.95s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.16s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.88s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.01s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.85s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.82s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.52s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.06s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.09s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.10s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.00s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.25s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.06s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.85s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.93s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.35s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.39s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.98s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.95s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.87s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.66s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.52s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.58s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.44s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.53s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.29s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.32s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.54s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.31s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.44s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.26s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.38s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.34s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.13s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.11s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.53s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.38s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.23s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.98s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.72s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.37s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.12s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.13s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.24s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.87s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.30s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.07s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.01s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.22s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.97s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.49s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.22s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.01s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.39s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.24s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.95s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.18s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.11s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.08s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.20s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.18s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.22s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.40s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.34s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.93s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.41s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.30s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.90s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.28s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.36s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.12s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.41s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.43s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.30s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.34s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.31s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.93s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.25s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.12s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.97s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.19s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.25s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.08s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.35s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.36s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.26s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.62s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.37s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.08s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.63s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.72s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.78s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.44s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.47s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.93s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.68s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.52s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.21s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.34s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.33s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.14s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.53s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.99s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.54s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.81s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.07s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.50s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.46s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.95s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.32s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.36s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.23s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.37s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.36s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.25s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.41s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.58s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.07s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.42s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.44s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.11s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.52s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.43s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.03s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.47s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.46s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.18s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.39s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.40s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.31s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.46s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.52s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.31s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.67s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.54s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.14s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.36s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.30s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.16s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.45s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.56s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.12s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.75s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.51s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.67s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.78s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.57s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.58s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.59s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.37s/it]
# pre-processing: 100%|██████████| 1/1 [00:08<00:00,  8.02s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.76s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.94s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.54s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.54s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.44s/it]
# pre-processing: 100%|██████████| 1/1 [00:08<00:00,  8.07s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.42s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.55s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.61s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.51s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.44s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.64s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.81s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.46s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.52s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.38s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.38s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.68s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.80s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.56s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.83s/it]
# pre-processing: 100%|██████████| 1/1 [00:08<00:00,  8.20s/it]
# pre-processing: 100%|██████████| 1/1 [00:08<00:00,  8.08s/it]
# pre-processing: 100%|██████████| 1/1 [00:08<00:00,  8.02s/it]
# pre-processing: 100%|██████████| 1/1 [00:08<00:00,  8.02s/it]
# pre-processing: 100%|██████████| 1/1 [00:08<00:00,  8.42s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.94s/it]
# pre-processing: 100%|██████████| 1/1 [00:09<00:00,  9.08s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.85s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.73s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.50s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.44s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.33s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.30s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.17s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.43s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.22s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.08s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.26s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.01s/it]
# pre-processing: 100%|██████████| 1/1 [00:06<00:00,  6.99s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.10s/it]
# pre-processing: 100%|██████████| 1/1 [00:06<00:00,  6.99s/it]
# pre-processing: 100%|██████████| 1/1 [00:06<00:00,  6.79s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.32s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.04s/it]
# pre-processing: 100%|██████████| 1/1 [00:06<00:00,  6.97s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.45s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.25s/it]
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  7.19s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.99s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.67s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.84s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.93s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.86s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.89s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.03s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.91s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.80s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.98s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.97s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.11s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.81s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.02s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.08s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.61s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.02s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.12s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.98s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.20s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.31s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.77s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.29s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.25s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.61s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.28s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.21s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.75s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.06s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.23s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.43s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.98s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.14s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.85s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.90s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.99s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.71s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.86s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.06s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.78s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.76s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.86s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.56s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.96s/it]
# pre-processing: 100%|██████████| 1/1 [00:03<00:00,  3.79s/it]

# %%
delete_simulated_files()

# %%
def check_best_params(Noizz):
    delete_simulated_files()
    subprocess.run(f'matlab -batch "Noizz = {Noizz}; Find_Best_Noizz"')
    simulated_files = list(map(str, Path('.\\').glob(f'Noizz*.csv')))
    simulated_df = pd.DataFrame({'file_path': simulated_files})
    simulated_df['state'] = 'normal'
    simulated_df['load_condition'] = 100
    simulated_df['experiment'] = 'experiment_2'
    simulated_df['phase'] = simulated_df.file_path.apply(get_phase)
    simulated_df['num_observations'] = simulated_df.file_path.apply(get_num_observations)
    simulated_df['measurement_id'] = simulated_df.apply(get_measurement_id, axis=1)
    simulated_df = simulated_df.reset_index(drop=True).set_index('measurement_id')
    sim_seg_1, _, sim_freqs_1 = preprocessing(simulated_df[simulated_df.phase == 1],
                                              'sim_data_1',
                                              segment_length=segment_length,
                                              step=shift,
                                              f_sampling=f_sampling,
                                              cutoff_freq=cutoff_freq)
    fig, ax = plot_single_segment_with_uncertainty(sim_seg_1, 
                                                   x_values=sim_freqs_1, 
                                                   n_std=3, 
                                                   title=f'Average Spectrum (simulated, all csv, phase 1, Noizz = {Noizz})',
                                                   inplace=True)
    
for Noizz in [opt_mean_Noizz, opt_std_Noizz]:
    check_best_params(round(Noizz, 4))
# Out:
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.69s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.79s/it]

# %%
grid_dict = {
    'Mean': {'Noizz': opt_mean_Noizz, 'MAE': opt_mean_mae},
    'Std': {'Noizz': opt_std_Noizz, 'MAE': opt_std_mae}
}
with open('best_grid_params.txt', 'w') as ouf:
    ouf.write(json.dumps(grid_dict))

# %%
class Objective:
    def __init__(self, optimized_value: str, low: float = 0, high: float = 50):
        self.optimized_value = optimized_value
        self.low = low
        self.high = high

    def __call__(self, trial: optuna.Trial) -> float:
        Noizz = trial.suggest_float('Noizz', self.low, self.high)
        delete_simulated_files()
        subprocess.run(f'matlab -batch "Noizz = {Noizz}; Find_Best_Noizz"')
        simulated_files = list(map(str, Path('.\\').glob(f'Noizz*.csv')))
        simulated_df = pd.DataFrame({'file_path': simulated_files})
        simulated_df['state'] = 'normal'
        simulated_df['load_condition'] = 100
        simulated_df['experiment'] = 'experiment_2'
        simulated_df['phase'] = simulated_df.file_path.apply(get_phase)
        simulated_df['num_observations'] = simulated_df.file_path.apply(get_num_observations)
        simulated_df['measurement_id'] = simulated_df.apply(get_measurement_id, axis=1)
        simulated_df = simulated_df.reset_index(drop=True).set_index('measurement_id')
        sim_seg[1], _, sim_freqs[1] = preprocessing(simulated_df[simulated_df.phase == 1],
                                                    'sim_data_1',
                                                    segment_length=segment_length,
                                                    step=shift,
                                                    f_sampling=f_sampling,
                                                    cutoff_freq=cutoff_freq
                                                    )
        sim_seg[2], _, sim_freqs[2] = preprocessing(simulated_df[simulated_df.phase == 2],
                                                    'sim_data_2',
                                                    segment_length=segment_length,
                                                    step=shift,
                                                    f_sampling=f_sampling,
                                                    cutoff_freq=cutoff_freq
                                                    )
        sim_seg[3], _, sim_freqs[3] = preprocessing(simulated_df[simulated_df.phase == 3],
                                                    'sim_data_3',
                                                    segment_length=segment_length,
                                                    step=shift,
                                                    f_sampling=f_sampling,
                                                    cutoff_freq=cutoff_freq
                                                    )
        all_mae = 0
        for phase in range(1, 4):
            sim_means[phase], sim_std[phase] = get_mean_and_std(sim_seg[phase])
            all_mae += MAE(real_std[phase], sim_std[phase]) if self.optimized_value == 'std' else MAE(real_means[phase], sim_means[phase])
        return all_mae

# %%
study_mean = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler())
study_mean.optimize(Objective(optimized_value='mean', low=0, high=10), n_trials=200)
best_params_mean = study_mean.best_params
best_score_mean = study_mean.best_value
# Out:
# [I 2025-09-27 22:08:07,459] A new study created in memory with name: no-name-5a2d2f39-2774-4c48-9f27-da60502c4830
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.53s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.88s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.82s/it]
# [I 2025-09-27 22:09:46,309] Trial 0 finished with value: 58.569034576416016 and parameters: {'Noizz': 5.325417950738859}. Best is trial 0 with value: 58.569034576416016.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.04s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.37s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.33s/it]
# [I 2025-09-27 22:11:42,152] Trial 1 finished with value: 57.67126274108887 and parameters: {'Noizz': 4.968171570120027}. Best is trial 1 with value: 57.67126274108887.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.54s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.26s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.44s/it]
# [I 2025-09-27 22:13:42,565] Trial 2 finished with value: 35.649375915527344 and parameters: {'Noizz': 0.8599513787752422}. Best is trial 2 with value: 35.649375915527344.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.79s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.79s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.64s/it]
# [I 2025-09-27 22:15:44,953] Trial 3 finished with value: 62.21893882751465 and parameters: {'Noizz': 7.057632377215567}. Best is trial 2 with value: 35.649375915527344.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.42s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.30s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.01s/it]
# [I 2025-09-27 22:17:41,177] Trial 4 finished with value: 55.44841766357422 and parameters: {'Noizz': 4.182887050030573}. Best is trial 2 with value: 35.649375915527344.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.09s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.83s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.03s/it]
# [I 2025-09-27 22:19:35,140] Trial 5 finished with value: 57.92473793029785 and parameters: {'Noizz': 5.066557270454773}. Best is trial 2 with value: 35.649375915527344.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.06s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.95s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.40s/it]
# [I 2025-09-27 22:21:24,134] Trial 6 finished with value: 56.923051834106445 and parameters: {'Noizz': 4.688724155410249}. Best is trial 2 with value: 35.649375915527344.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.05s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.70s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.61s/it]
# [I 2025-09-27 22:23:13,304] Trial 7 finished with value: 58.09917640686035 and parameters: {'Noizz': 5.135386860955899}. Best is trial 2 with value: 35.649375915527344.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.82s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.51s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.75s/it]
# [I 2025-09-27 22:25:00,148] Trial 8 finished with value: 53.68288803100586 and parameters: {'Noizz': 3.64819133552182}. Best is trial 2 with value: 35.649375915527344.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.80s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.69s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.65s/it]
# [I 2025-09-27 22:26:47,173] Trial 9 finished with value: 60.21073913574219 and parameters: {'Noizz': 6.045881510667016}. Best is trial 2 with value: 35.649375915527344.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.77s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.61s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.71s/it]
# [I 2025-09-27 22:28:33,740] Trial 10 finished with value: 34.64156627655029 and parameters: {'Noizz': 0.7878889392787776}. Best is trial 10 with value: 34.64156627655029.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.60s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.73s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.43s/it]
# [I 2025-09-27 22:30:17,868] Trial 11 finished with value: 11.56450366973877 and parameters: {'Noizz': 0.07860022040277703}. Best is trial 11 with value: 11.56450366973877.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.74s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.91s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.79s/it]
# [I 2025-09-27 22:32:04,802] Trial 12 finished with value: 30.434420585632324 and parameters: {'Noizz': 0.005895685625244451}. Best is trial 11 with value: 11.56450366973877.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.74s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.87s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.84s/it]
# [I 2025-09-27 22:33:54,469] Trial 13 finished with value: 65.9682846069336 and parameters: {'Noizz': 9.413366271590254}. Best is trial 11 with value: 11.56450366973877.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  5.00s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.64s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.58s/it]
# [I 2025-09-27 22:35:41,673] Trial 14 finished with value: 47.86367702484131 and parameters: {'Noizz': 2.3230043175079156}. Best is trial 11 with value: 11.56450366973877.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.98s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.77s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.67s/it]
# [I 2025-09-27 22:37:29,936] Trial 15 finished with value: 13.793581008911133 and parameters: {'Noizz': 0.10318772405471856}. Best is trial 11 with value: 11.56450366973877.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.80s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.63s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.25s/it]
# [I 2025-09-27 22:39:18,309] Trial 16 finished with value: 46.704331398010254 and parameters: {'Noizz': 2.1228470223198332}. Best is trial 11 with value: 11.56450366973877.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.46s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.44s/it]
# [I 2025-09-27 22:41:05,275] Trial 17 finished with value: 49.74607276916504 and parameters: {'Noizz': 2.6885051563684113}. Best is trial 11 with value: 11.56450366973877.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.13s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.80s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.72s/it]
# [I 2025-09-27 22:42:56,127] Trial 18 finished with value: 41.23406505584717 and parameters: {'Noizz': 1.3786204427672295}. Best is trial 11 with value: 11.56450366973877.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.74s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.68s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.61s/it]
# [I 2025-09-27 22:44:45,502] Trial 19 finished with value: 10.09447717666626 and parameters: {'Noizz': 0.06295420119795146}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.30s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.72s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.81s/it]
# [I 2025-09-27 22:46:33,689] Trial 20 finished with value: 52.144914627075195 and parameters: {'Noizz': 3.2382328325041}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.01s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.90s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.38s/it]
# [I 2025-09-27 22:48:36,677] Trial 21 finished with value: 14.800373554229736 and parameters: {'Noizz': 0.11572261215623991}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.50s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.89s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.72s/it]
# [I 2025-09-27 22:50:39,583] Trial 22 finished with value: 42.855835914611816 and parameters: {'Noizz': 1.569837040168899}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.30s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.60s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.53s/it]
# [I 2025-09-27 22:52:41,568] Trial 23 finished with value: 29.167180061340332 and parameters: {'Noizz': 0.00649896675779716}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.85s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.83s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.09s/it]
# [I 2025-09-27 22:54:49,449] Trial 24 finished with value: 37.631951332092285 and parameters: {'Noizz': 1.0197324553644544}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.36s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.36s/it]
# [I 2025-09-27 22:56:57,026] Trial 25 finished with value: 64.13090324401855 and parameters: {'Noizz': 8.175865964353877}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.39s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.09s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.15s/it]
# [I 2025-09-27 22:58:58,609] Trial 26 finished with value: 42.87810707092285 and parameters: {'Noizz': 1.5726115836426224}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.33s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.72s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.49s/it]
# [I 2025-09-27 23:01:00,083] Trial 27 finished with value: 51.18463897705078 and parameters: {'Noizz': 3.005877501325442}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.71s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.82s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.65s/it]
# [I 2025-09-27 23:03:06,422] Trial 28 finished with value: 46.80832004547119 and parameters: {'Noizz': 2.1400778650940957}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:06<00:00,  6.35s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.01s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.95s/it]
# [I 2025-09-27 23:05:20,344] Trial 29 finished with value: 36.10244655609131 and parameters: {'Noizz': 0.894316906284623}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.25s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.56s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.41s/it]
# [I 2025-09-27 23:07:27,777] Trial 30 finished with value: 60.42169952392578 and parameters: {'Noizz': 6.14518862856463}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.71s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.15s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.19s/it]
# [I 2025-09-27 23:09:30,877] Trial 31 finished with value: 23.39664936065674 and parameters: {'Noizz': 0.28219619139155744}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.03s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.62s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.55s/it]
# [I 2025-09-27 23:11:35,729] Trial 32 finished with value: 30.371825218200684 and parameters: {'Noizz': 0.5395728622668997}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.96s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.97s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.55s/it]
# [I 2025-09-27 23:13:35,864] Trial 33 finished with value: 42.249796867370605 and parameters: {'Noizz': 1.4960337911246202}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.45s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.52s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.65s/it]
# [I 2025-09-27 23:15:39,975] Trial 34 finished with value: 29.86796474456787 and parameters: {'Noizz': 0.5155847790869144}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.04s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.96s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.64s/it]
# [I 2025-09-27 23:17:41,912] Trial 35 finished with value: 37.28314208984375 and parameters: {'Noizz': 0.9897944979092057}. Best is trial 19 with value: 10.09447717666626.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.28s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.84s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.60s/it]
# [I 2025-09-27 23:19:43,319] Trial 36 finished with value: 8.624152898788452 and parameters: {'Noizz': 0.042410498986164454}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.92s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.61s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.40s/it]
# [I 2025-09-27 23:21:44,342] Trial 37 finished with value: 45.41685104370117 and parameters: {'Noizz': 1.9202457047567587}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.42s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.76s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.27s/it]
# [I 2025-09-27 23:23:49,344] Trial 38 finished with value: 53.8831787109375 and parameters: {'Noizz': 3.705257748924018}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.38s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.38s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.97s/it]
# [I 2025-09-27 23:25:53,464] Trial 39 finished with value: 39.62791156768799 and parameters: {'Noizz': 1.2071999094101802}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.09s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.49s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.44s/it]
# [I 2025-09-27 23:27:52,752] Trial 40 finished with value: 31.048882484436035 and parameters: {'Noizz': 0.5734522732370643}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.20s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.45s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.37s/it]
# [I 2025-09-27 23:29:52,543] Trial 41 finished with value: 15.29285717010498 and parameters: {'Noizz': 0.018883121335469107}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.02s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.37s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.10s/it]
# [I 2025-09-27 23:31:50,898] Trial 42 finished with value: 30.758601188659668 and parameters: {'Noizz': 0.5586886418162127}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.92s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.53s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.96s/it]
# [I 2025-09-27 23:33:48,041] Trial 43 finished with value: 25.697516441345215 and parameters: {'Noizz': 0.35127615378547855}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.03s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.31s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.29s/it]
# [I 2025-09-27 23:35:45,170] Trial 44 finished with value: 44.20181083679199 and parameters: {'Noizz': 1.7458505451526456}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.03s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.45s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.27s/it]
# [I 2025-09-27 23:37:42,455] Trial 45 finished with value: 37.700448989868164 and parameters: {'Noizz': 1.0257004112525945}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.97s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.18s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.09s/it]
# [I 2025-09-27 23:39:39,017] Trial 46 finished with value: 49.24850654602051 and parameters: {'Noizz': 2.586692842708317}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.01s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.12s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.07s/it]
# [I 2025-09-27 23:41:29,734] Trial 47 finished with value: 57.37717247009277 and parameters: {'Noizz': 0.0007429737882686804}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.20s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.05s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.93s/it]
# [I 2025-09-27 23:43:23,665] Trial 48 finished with value: 62.98466491699219 and parameters: {'Noizz': 7.486018967964624}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.09s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.30s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.29s/it]
# [I 2025-09-27 23:45:25,815] Trial 49 finished with value: 66.6596908569336 and parameters: {'Noizz': 9.925644445366554}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.61s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.34s/it]
# [I 2025-09-27 23:47:22,946] Trial 50 finished with value: 55.58180618286133 and parameters: {'Noizz': 4.226311505727723}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.89s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.28s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.30s/it]
# [I 2025-09-27 23:49:22,395] Trial 51 finished with value: 35.607229232788086 and parameters: {'Noizz': 0.003961189071871443}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.01s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.41s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.42s/it]
# [I 2025-09-27 23:51:19,569] Trial 52 finished with value: 25.648221015930176 and parameters: {'Noizz': 0.3496519437624361}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.03s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.27s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.32s/it]
# [I 2025-09-27 23:53:17,255] Trial 53 finished with value: 34.080668449401855 and parameters: {'Noizz': 0.750156295128707}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.67s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.51s/it]
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.54s/it]
# [I 2025-09-27 23:55:19,768] Trial 54 finished with value: 40.114033699035645 and parameters: {'Noizz': 1.257105946392712}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.94s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.84s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.43s/it]
# [I 2025-09-27 23:57:21,554] Trial 55 finished with value: 23.322608470916748 and parameters: {'Noizz': 0.28019021892736173}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.24s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.50s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.44s/it]
# [I 2025-09-27 23:59:20,516] Trial 56 finished with value: 35.372562408447266 and parameters: {'Noizz': 0.839587822461196}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:05<00:00,  5.48s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.67s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.46s/it]
# [I 2025-09-28 00:01:20,510] Trial 57 finished with value: 40.424652099609375 and parameters: {'Noizz': 1.2898948835278492}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.82s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.40s/it]
# pre-processing: 100%|██████████| 1/1 [00:04<00:00,  4.42s/it]
# [I 2025-09-28 00:03:20,428] Trial 58 finished with value: 45.21501922607422 and parameters: {'Noizz': 1.8902021112875844}. Best is trial 36 with value: 8.624152898788452.
# pre-processing: 100%|██████████| 1/1 [00:07<00:00,  8.00s/it]
# pre-processing: 100%|██████████| 1/1 [00:08<00:00,  8.18s/it]
# pre-processing: 100%|██████████| 1/1 [00:08<00:00,  8.29s/it]
# [I 2025-09-28 00:05:30,282] Trial 59 finished with value: 8.656202793121338 and parameters: {'Noizz': 0.043316975093263516}. Best is trial 36 with value: 8.624152898788452.

# %%
study_std = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler())
study_std.optimize(Objective(optimized_value='std', low=0, high=10), n_trials=200)
best_params_std = study_std.best_params
best_score_std = study_std.best_value

# %%
optuna_dict = {
    'Mean': {'Noizz': best_params_mean['Noizz'], 'MAE': best_score_mean},
    'Std': {'Noizz': best_params_std['Noizz'], 'MAE': best_score_std}
} 
with open('best_optuna_params.txt', 'w') as ouf:
    ouf.write(json.dumps(optuna_dict))

# %%
delete_simulated_files()

# %%
best_mean_Noizz = round(best_params_mean['Noizz'], 4)
best_std_Noizz = round(best_params_std['Noizz'], 4)
   
for Noizz in [best_mean_Noizz, best_std_Noizz]:
    check_best_params(Noizz)
